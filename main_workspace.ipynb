# %%
# !pip install dlib
# !pip install --upgrade imutils
# !pip install mediapipe
# !pip install torch

# %%
# !pip install -U matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 30.5 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 54.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 31.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [matplotlib]5 [matplotlib]
# ...

# %%
# !pip install Config

# %%
import torch 
import torch.nn as nn
import torch.optim as optim 
import torchvision 
from  torchvision import transforms
import torchvision.datasets as datasets  
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
# import cv2 
import os # for file path 
import sys
# import dlib
import numpy as np #to open npz files 
from numpy import load
from matplotlib import pyplot as plt #for showing image 
import glob # for reading file in folder 
# from imutils import face_utils
from torchvision import datasets, models, transforms
# import imutils
import argparse
# import mediapipe as mp
# from scipy.spatial import distance
from torchvision.io import read_image
# from google.colab.patches import cv2_imshow

# %%
# !pip install kagglehub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kagglehub]
# ...

# %%
# !pip install kagglehub[pandas-datasets]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 107.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# ...

# %%
# !pip install kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [kaggle]2m3/4 [kaggle]
# ...

# %%
# !pip install gdown
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [gdown]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !gdown '1P56XVe21zwg8x2oBGZ3cCM19w_D-jVj-' #put my private key in gdrive (not safe btw but me lazy)
# !mv kaggle\ \(3\).json kaggle.json
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1P56XVe21zwg8x2oBGZ3cCM19w_D-jVj-
# To: /workspace/kaggle (3).json
# 100%|█████████████████████████████████████████| 63.0/63.0 [00:00<00:00, 312kB/s]

# %%
# !rm -f ~/.kaggle

# %%
# !mkdir -p ~/.kaggle

# %%
# !mv kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d electraawais/cityscape-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/electraawais/cityscape-dataset
# License(s): MIT

# %%
# !unzip cityscape-dataset.zip -d /dataset
# Out:
# Archive:  cityscape-dataset.zip
#   inflating: /dataset/Cityscape Dataset/README
#   inflating: /dataset/Cityscape Dataset/leftImg8bit/test/berlin/berlin_000000_000019_leftImg8bit.png
#   inflating: /dataset/Cityscape Dataset/leftImg8bit/test/berlin/berlin_000001_000019_leftImg8bit.png
#   inflating: /dataset/Cityscape Dataset/leftImg8bit/test/berlin/berlin_000002_000019_leftImg8bit.png
#   inflating: /dataset/Cityscape Dataset/leftImg8bit/test/berlin/berlin_000003_000019_leftImg8bit.png
#   inflating: /dataset/Cityscape Dataset/leftImg8bit/test/berlin/berlin_000004_000019_leftImg8bit.png
#   inflating: /dataset/Cityscape Dataset/leftImg8bit/test/berlin/berlin_000005_000019_leftImg8bit.png
#   inflating: /dataset/Cityscape Dataset/leftImg8bit/test/berlin/berlin_000006_000019_leftImg8bit.png
#   inflating: /dataset/Cityscape Dataset/leftImg8bit/test/berlin/berlin_000007_000019_leftImg8bit.png
# ...

# %%
print("check")
# Out:
# check

# %%
items = os.listdir('/content/drive/MyDrive/Dataset3')
img_dir = '/content/drive/MyDrive/Dataset3'

# %%
LandscapeDataset("","")

# %%
r

# %%
# !mkdir -p train/data
# !mkdir -p train/data/label
# !mkdir -p train/data/input

# %%
# !find "/dataset/Cityscape Dataset/leftImg8bit/train" -type f -exec cp {} train/data/label \;
# !find "/dataset/Fine Annotations/gtFine/train" -type f -exec cp {} train/data/input \;

# %%
dataset/Cityscape Dataset/leftImg8bit/train/bremen

# %%
# !mkdir -p val/data
# !mkdir -p val/data/label
# !mkdir -p val/data/input

# %%
# !find "/dataset/Cityscape Dataset/leftImg8bit/val" -type f -exec cp {} val/data/label \;
# !find "/dataset/Fine Annotations/gtFine/val" -type f -exec cp {} val/data/input \;

# %%
# !mkdir -p test/data
# !mkdir -p test/data/label
# !mkdir -p test/data/input

# %%
# !find "/dataset/Cityscape Dataset/leftImg8bit/test" -type f -exec cp {} test/data/label \;
# !find "/dataset/Fine Annotations/gtFine/test" -type f -exec cp {} test/data/input \;

# %%
import os
import numpy as np
from PIL import Image
import torch
from torch.utils.data import Dataset


class LandscapeDataset(Dataset):
    def __init__(self, root_dir):
        self.input_dir = os.path.join(root_dir, "input")
        self.label_dir = os.path.join(root_dir, "label")
        self.image_names = [
            f.replace("_gtFine_color.png", "")
            for f in os.listdir(self.input_dir)
            if f.endswith("_gtFine_color.png")
        ]

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, index):
        name = self.image_names[index]

        input_path = os.path.join(self.input_dir, f"{name}_gtFine_color.png")
        label_path = os.path.join(self.label_dir, f"{name}_leftImg8bit.png")

        # Read both images
        input_image = np.array(Image.open(input_path).convert("RGB"))
        target_image = np.array(Image.open(label_path).convert("RGB"))

        # Convert to PyTorch tensors (C, H, W)
        input_tensor = torch.from_numpy(input_image).permute(2, 0, 1).float() / 255.0
        target_tensor = torch.from_numpy(target_image).permute(2, 0, 1).float() / 255.0

        return input_tensor, target_tensor

# %%
from torchvision.utils import save_image

dataset = LandscapeDataset("/workspace/train/data")
loader = DataLoader(dataset, batch_size=8, shuffle=True)

for x, y in loader:
    print(x.shape, y.shape)
    
    # Save a few sample pairs to verify visually
    save_image(x, "input_batch.png")
    save_image(y, "target_batch.png")
    print("Saved sample images: input_batch.png and target_batch.png")
    break
# Out:
# torch.Size([8, 3, 1024, 2048]) torch.Size([8, 3, 1024, 2048])
# Saved sample images: input_batch.png and target_batch.png

# %%
import torch
import torch.nn as nn

class Block(nn.Module):
    def __init__(self, in_channels, out_channels, down=True, act="relu", use_dropout=False):
        super(Block, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 4, 2, 1, bias=False, padding_mode="reflect")
            if down
            else nn.ConvTranspose2d(in_channels, out_channels, 4, 2, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU() if act == "relu" else nn.LeakyReLU(0.2),
        )

        self.use_dropout = use_dropout
        self.dropout = nn.Dropout(0.5)
        self.down = down

    def forward(self, x):
        x = self.conv(x)
        return self.dropout(x) if self.use_dropout else x


class Generator(nn.Module):
    def __init__(self, in_channels=3, features=64):
        super().__init__()
        self.initial_down = nn.Sequential(
            nn.Conv2d(in_channels, features, 4, 2, 1, padding_mode="reflect"),
            nn.LeakyReLU(0.2),
        )
        self.down1 = Block(features, features * 2, down=True, act="leaky", use_dropout=False)
        self.down2 = Block(
            features * 2, features * 4, down=True, act="leaky", use_dropout=False
        )
        self.down3 = Block(
            features * 4, features * 8, down=True, act="leaky", use_dropout=False
        )
        self.down4 = Block(
            features * 8, features * 8, down=True, act="leaky", use_dropout=False
        )
        self.down5 = Block(
            features * 8, features * 8, down=True, act="leaky", use_dropout=False
        )
        self.down6 = Block(
            features * 8, features * 8, down=True, act="leaky", use_dropout=False
        )
        self.bottleneck = nn.Sequential(
            nn.Conv2d(features * 8, features * 8, 4, 2, 1), nn.ReLU()
        )

        self.up1 = Block(features * 8, features * 8, down=False, act="relu", use_dropout=True)
        self.up2 = Block(
            features * 8 * 2, features * 8, down=False, act="relu", use_dropout=True
        )
        self.up3 = Block(
            features * 8 * 2, features * 8, down=False, act="relu", use_dropout=True
        )
        self.up4 = Block(
            features * 8 * 2, features * 8, down=False, act="relu", use_dropout=False
        )
        self.up5 = Block(
            features * 8 * 2, features * 4, down=False, act="relu", use_dropout=False
        )
        self.up6 = Block(
            features * 4 * 2, features * 2, down=False, act="relu", use_dropout=False
        )
        self.up7 = Block(features * 2 * 2, features, down=False, act="relu", use_dropout=False)
        self.final_up = nn.Sequential(
            nn.ConvTranspose2d(features * 2, in_channels, kernel_size=4, stride=2, padding=1),
            nn.Tanh(),
        )

    def forward(self, x):
        d1 = self.initial_down(x)
        d2 = self.down1(d1)
        d3 = self.down2(d2)
        d4 = self.down3(d3)
        d5 = self.down4(d4)
        d6 = self.down5(d5)
        d7 = self.down6(d6)
        bottleneck = self.bottleneck(d7)
        up1 = self.up1(bottleneck)
        up2 = self.up2(torch.cat([up1, d7], 1))
        up3 = self.up3(torch.cat([up2, d6], 1))
        up4 = self.up4(torch.cat([up3, d5], 1))
        up5 = self.up5(torch.cat([up4, d4], 1))
        up6 = self.up6(torch.cat([up5, d3], 1))
        up7 = self.up7(torch.cat([up6, d2], 1))
        return self.final_up(torch.cat([up7, d1], 1))


def test():
    x = torch.randn((1, 3, 256, 256))
    model = Generator(in_channels=3, features=64)
    preds = model(x)
    print(preds.shape)


if __name__ == "__main__":
    test()
# Out:
# torch.Size([1, 3, 256, 256])

# %%
import torch
import torch.nn as nn


class CNNBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride):
        super(CNNBlock, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(
                in_channels, out_channels, 4, stride, 1, bias=False, padding_mode="reflect"
            ),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.conv(x)


class Discriminator(nn.Module):
    def __init__(self, in_channels=3, features=[64, 128, 256, 512]):
        super().__init__()
        self.initial = nn.Sequential(
            nn.Conv2d(
                in_channels * 2,
                features[0],
                kernel_size=4,
                stride=2,
                padding=1,
                padding_mode="reflect",
            ),
            nn.LeakyReLU(0.2),
        )

        layers = []
        in_channels = features[0]
        for feature in features[1:]:
            layers.append(
                CNNBlock(in_channels, feature, stride=1 if feature == features[-1] else 2),
            )
            in_channels = feature

        layers.append(
            nn.Conv2d(
                in_channels, 1, kernel_size=4, stride=1, padding=1, padding_mode="reflect"
            ),
        )

        self.model = nn.Sequential(*layers)

    def forward(self, x, y):
        x = torch.cat([x, y], dim=1)
        x = self.initial(x)
        x = self.model(x)
        return x


def test():
    x = torch.randn((1, 3, 256, 256))
    y = torch.randn((1, 3, 256, 256))
    model = Discriminator(in_channels=3)
    preds = model(x, y)
    print(model)
    print(preds.shape)


if __name__ == "__main__":
    test()
# Out:
# Discriminator(
#   (initial): Sequential(
#     (0): Conv2d(6, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), padding_mode=reflect)
#     (1): LeakyReLU(negative_slope=0.2)
#   )
#   (model): Sequential(
#     (0): CNNBlock(
#       (conv): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False, padding_mode=reflect)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (1): CNNBlock(
#       (conv): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False, padding_mode=reflect)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (2): CNNBlock(
#       (conv): Sequential(
# ...

# %%
class Config:
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    LEARNING_RATE = 2e-4
    BATCH_SIZE = 8
    NUM_EPOCHS = 100
    NUM_WORKERS = 4
    L1_LAMBDA = 100
    LOAD_MODEL = False
    SAVE_MODEL = True

    TRAIN_DIR = "/workspace/train/data"
    VAL_DIR = "/workspace/val/data"

    CHECKPOINT_GEN = "checkpoints/gen.pth.tar"
    CHECKPOINT_DISC = "checkpoints/disc.pth.tar"
    LOG_FILE = "loss_log.csv"


torch.backends.cudnn.benchmark = True

# %%
import torch
from torchvision.utils import save_image

def save_some_examples(gen, val_loader, folder, epoch, device):
    os.makedirs(folder, exist_ok=True)
    gen.eval()
    x, y = next(iter(val_loader))
    x, y = x.to(device), y.to(device)
    with torch.no_grad():
        y_fake = gen(x)
        y_fake = y_fake * 0.5 + 0.5  # normalize back to [0,1]
        save_image(y_fake, f"{folder}/y_gen_{epoch}.png")
        save_image(x * 0.5 + 0.5, f"{folder}/input_{epoch}.png")
        save_image(y * 0.5 + 0.5, f"{folder}/label_{epoch}.png")
    gen.train()

def save_checkpoint(model, filename="my_checkpoint.pth.tar"):
    print("=> Saving checkpoint")
    checkpoint = {
        "state_dict": model.state_dict(),
    }
    torch.save(checkpoint, filename)


def load_checkpoint(checkpoint_file, model, optimizer, lr):
    print("=> Loading checkpoint")
    checkpoint = torch.load(checkpoint_file, map_location=Config.DEVICE)
    model.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])

    # If we don't do this then it will just have learning rate of old checkpoint
    # and it will lead to many hours of debugging \:
    for param_group in optimizer.param_groups:
        param_group["lr"] = lr

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm import tqdm
from torchvision.utils import save_image
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.benchmark = True


class Config:
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    LEARNING_RATE = 2e-4
    BATCH_SIZE = 8
    NUM_EPOCHS = 100
    NUM_WORKERS = 4
    L1_LAMBDA = 100
    LOAD_MODEL = True
    SAVE_MODEL = True

    TRAIN_DIR = "/workspace/train/data"
    VAL_DIR = "/workspace/val/data"

    CHECKPOINT_GEN = "checkpoints/gen.pth.tar"
    CHECKPOINT_DISC = "checkpoints/disc.pth.tar"


def save_checkpoint(model, optimizer, filename):
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    print(f"Saving checkpoint to {filename}...")
    torch.save({"state_dict": model.state_dict(), "optimizer": optimizer.state_dict()}, filename)


def load_checkpoint(filename, model, optimizer, lr):
    print(f"Loading checkpoint from {filename}...")
    checkpoint = torch.load(filename, map_location=Config.DEVICE)
    model.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    for param_group in optimizer.param_groups:
        param_group["lr"] = lr


def save_some_examples(gen, val_loader, folder, epoch):
    os.makedirs(folder, exist_ok=True)
    x, y = next(iter(val_loader))
    x, y = x.to(Config.DEVICE), y.to(Config.DEVICE)
    gen.eval()
    with torch.no_grad():
        y_fake = gen(x)
        y_fake = (y_fake * 0.5 + 0.5)
    save_image(y_fake, f"{folder}/y_gen_{epoch}.png")
    save_image(x * 0.5 + 0.5, f"{folder}/input_{epoch}.png")
    save_image(y * 0.5 + 0.5, f"{folder}/label_{epoch}.png")
    gen.train()


def plot_and_save_losses(gen_losses, disc_losses, epoch):
    os.makedirs("loss_graphs", exist_ok=True)
    plt.figure(figsize=(8, 5))
    plt.plot(gen_losses, label='Generator Loss', color='blue')
    plt.plot(disc_losses, label='Discriminator Loss', color='red')
    plt.title(f'Loss Graph - Epoch {epoch+1}')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig(f"loss_graphs/loss_epoch_{epoch+1}.png", dpi=300, bbox_inches='tight')
    plt.close()


def train_fn(disc, gen, loader, opt_disc, opt_gen, l1_loss, bce, g_scaler, d_scaler):
    loop = tqdm(loader, leave=True)
    gen_loss_list = []
    disc_loss_list = []

    for idx, (x, y) in enumerate(loop):
        x = x.to(Config.DEVICE, non_blocking=True)
        y = y.to(Config.DEVICE, non_blocking=True)

        # --- Discriminator ---
        with torch.amp.autocast("cuda"):
            y_fake = gen(x)
            D_real = disc(x, y)
            D_real_loss = bce(D_real, torch.ones_like(D_real))
            D_fake = disc(x, y_fake.detach())
            D_fake_loss = bce(D_fake, torch.zeros_like(D_fake))
            D_loss = (D_real_loss + D_fake_loss) / 2

        disc.zero_grad(set_to_none=True)
        d_scaler.scale(D_loss).backward()
        d_scaler.step(opt_disc)
        d_scaler.update()

        # --- Generator ---
        with torch.amp.autocast("cuda"):
            D_fake = disc(x, y_fake)
            G_fake_loss = bce(D_fake, torch.ones_like(D_fake))
            L1 = l1_loss(y_fake, y) * Config.L1_LAMBDA
            G_loss = G_fake_loss + L1

        opt_gen.zero_grad(set_to_none=True)
        g_scaler.scale(G_loss).backward()
        g_scaler.step(opt_gen)
        g_scaler.update()

        gen_loss_list.append(G_loss.item())
        disc_loss_list.append(D_loss.item())

        if idx % 10 == 0:
            loop.set_postfix(D_real=torch.sigmoid(D_real).mean().item(),
                             D_fake=torch.sigmoid(D_fake).mean().item())

    return gen_loss_list, disc_loss_list


def main():
    disc = Discriminator(in_channels=3).to(Config.DEVICE)
    gen = Generator(in_channels=3, features=64).to(Config.DEVICE)

    opt_disc = optim.Adam(disc.parameters(), lr=Config.LEARNING_RATE, betas=(0.5, 0.999))
    opt_gen = optim.Adam(gen.parameters(), lr=Config.LEARNING_RATE, betas=(0.5, 0.999))

    BCE = nn.BCEWithLogitsLoss()
    L1_LOSS = nn.L1Loss()

    if Config.LOAD_MODEL:
        load_checkpoint(Config.CHECKPOINT_GEN, gen, opt_gen, Config.LEARNING_RATE)
        load_checkpoint(Config.CHECKPOINT_DISC, disc, opt_disc, Config.LEARNING_RATE)

    train_dataset = LandscapeDataset(root_dir=Config.TRAIN_DIR)
    train_loader = DataLoader(train_dataset, batch_size=Config.BATCH_SIZE,
                              shuffle=True, num_workers=Config.NUM_WORKERS, pin_memory=True)
    val_dataset = LandscapeDataset(root_dir=Config.VAL_DIR)
    val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)

    g_scaler = torch.amp.GradScaler("cuda")
    d_scaler = torch.amp.GradScaler("cuda")

    gen_losses = []
    disc_losses = []

    for epoch in range(Config.NUM_EPOCHS):
        print(f"\nEpoch [{epoch+1}/{Config.NUM_EPOCHS}]")
        g_loss, d_loss = train_fn(disc, gen, train_loader, opt_disc, opt_gen, L1_LOSS, BCE, g_scaler, d_scaler)
        gen_losses.extend(g_loss)
        disc_losses.extend(d_loss)

        # save checkpoints every 5 epochs
        if Config.SAVE_MODEL and (epoch + 1) % 5 == 0:
            save_checkpoint(gen, opt_gen, filename=Config.CHECKPOINT_GEN)
            save_checkpoint(disc, opt_disc, filename=Config.CHECKPOINT_DISC)

        # save generated examples
        save_some_examples(gen, val_loader, folder="evaluation", epoch=epoch)

        # save loss arrays
        np.save("gen_losses.npy", np.array(gen_losses))
        np.save("disc_losses.npy", np.array(disc_losses))

        # plot and save loss graph each epoch
        plot_and_save_losses(gen_losses, disc_losses, epoch)

        print(f"✅ Saved loss graph for epoch {epoch+1}")

    print("✅ Training complete — all loss graphs saved in 'loss_graphs/'")


if __name__ == "__main__":
    main()
# Out:
# Loading checkpoint from checkpoints/gen.pth.tar...
# Loading checkpoint from checkpoints/disc.pth.tar...
#
# Epoch [1/100]
# 100%|██████████| 372/372 [02:43<00:00,  2.27it/s, D_fake=0.35, D_real=0.467]
# ✅ Saved loss graph for epoch 1
#
# Epoch [2/100]
# 100%|██████████| 372/372 [02:44<00:00,  2.26it/s, D_fake=0.405, D_real=0.672]
# ✅ Saved loss graph for epoch 2
#
# Epoch [3/100]
# 100%|██████████| 372/372 [02:47<00:00,  2.22it/s, D_fake=0.387, D_real=0.537]
# ✅ Saved loss graph for epoch 3
#
# Epoch [4/100]
# 100%|██████████| 372/372 [02:45<00:00,  2.25it/s, D_fake=0.492, D_real=0.323]
# ✅ Saved loss graph for epoch 4
#
# Epoch [5/100]
# 100%|██████████| 372/372 [02:44<00:00,  2.26it/s, D_fake=0.412, D_real=0.69]
# Saving checkpoint to checkpoints/gen.pth.tar...
# Saving checkpoint to checkpoints/disc.pth.tar...
# ✅ Saved loss graph for epoch 5
#
# Epoch [6/100]
# 100%|██████████| 372/372 [02:47<00:00,  2.22it/s, D_fake=0.477, D_real=0.432]
# ✅ Saved loss graph for epoch 6
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example: gen_losses is a long list (length = 372 * num_epochs)
# Change 372 to match your actual number of batches per epoch
batches_per_epoch = 372

# Convert to NumPy for easier slicing
gen_losses_arr = np.array(gen_losses)

# Compute average loss per epoch
epoch_means = [
    np.mean(gen_losses_arr[i:i + batches_per_epoch])
    for i in range(0, len(gen_losses_arr), batches_per_epoch)
]

# Plot
plt.figure(figsize=(8, 5))
plt.plot(epoch_means, marker='o', label='Generator Avg Loss per Epoch', color='blue')
plt.title("Generator Average Loss per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Average Loss")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[133], line 9
#       6 batches_per_epoch = 372
#       8 # Convert to NumPy for easier slicing
# ----> 9 gen_losses_arr = np.array(gen_losses)
#      11 # Compute average loss per epoch
#      12 epoch_means = [
#      13     np.mean(gen_losses_arr[i:i + batches_per_epoch])
#      14     for i in range(0, len(gen_losses_arr), batches_per_epoch)
#      15 ]
#
# NameError: name 'gen_losses' is not defined

# %%
# -----------------------------
# 📈 PLOTTING FUNCTION
# -----------------------------
def plot_losses(csv_file):
    data = pd.read_csv(csv_file)
    plt.figure(figsize=(10, 6))
    plt.plot(data["epoch"], data["train_D_loss"], label="Train D Loss", color="red")
    plt.plot(data["epoch"], data["val_D_loss"], label="Val D Loss", color="orange")
    plt.plot(data["epoch"], data["train_G_loss"], label="Train G Loss", color="blue")
    plt.plot(data["epoch"], data["val_G_loss"], label="Val G Loss", color="green")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training vs Validation Loss (Generator & Discriminator)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("loss_plot.png")
    plt.show()
